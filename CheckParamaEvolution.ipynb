# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from array import array
import os
import sys
import ROOT
from ROOT import TVectorD, TMatrix, TMath, TVector3, TGraphErrors, TFile, TTree, gRandom, gPad, gROOT, gVirtualX, kTRUE, kRed, TProfile, gStyle,  TFile, gSystem
import sys 
import os
sys.path.append(os.path.abspath("/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/fastMCKalman/fastMCKalman/MC/"))
from fastSimulation import *

# %% [markdown]
# # Reading the files

# %%
folder="/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/RecoFullReco/"
inputData = folder+"fastParticle.list"
ROOT.initTreeFast(inputData)
tree=ROOT.treeFast
treeSeed = ROOT.treeSeed

# %%
event = 0

# %%
tree.SetMarkerSize(2)

hq0 = ROOT.TCanvas("hq0","hq0",1000,500)
tree.SetMarkerColor(4)
tree.Draw("part.fParamIn[].fP[0]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[0]!=0","",1,event)
tree.SetMarkerColor(2)
tree.Draw("part.fParamMC[].fP[0]:Iteration$","part.fParamMC[].fP[0]!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("param 0 evolution;Iterator;param0")
hq0.Draw()

hq1 = ROOT.TCanvas("hq1","hq1",1000,500)
tree.SetMarkerColor(4)
tree.Draw("part.fParamIn[].fP[1]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[1]!=0","",1,event)
tree.SetMarkerColor(2)
tree.Draw("part.fParamMC[].fP[1]:Iteration$","part.fParamMC[].fP[1]!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("param 1 evolution;Iterator;param1")
hq1.Draw()

hq2 = ROOT.TCanvas("hq2","hq2",1000,500)
tree.SetMarkerColor(4)
tree.Draw("part.fParamIn[].fP[2]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[2]!=0","",1,event)
tree.SetMarkerColor(2)
tree.Draw("part.fParamMC[].fP[2]:Iteration$","part.fParamMC[].fP[2]!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("param 2 evolution;Iterator;param2")
hq2.Draw()

hq3 = ROOT.TCanvas("hq3","hq3",1000,500)
tree.SetMarkerColor(4)
tree.Draw("part.fParamIn[].fP[3]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[3]!=0","",1,event)
tree.SetMarkerColor(2)
tree.Draw("part.fParamMC[].fP[3]:Iteration$","part.fParamMC[].fP[3]!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("param 3 evolution;Iterator;param3")
hq3.Draw()

hq4 = ROOT.TCanvas("hq4","hq4",1000,500)
tree.SetMarkerColor(4)
tree.Draw("part.fParamIn[].fP[4]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[4]!=0","",1,event)
tree.SetMarkerColor(2)
tree.Draw("part.fParamMC[].fP[4]:Iteration$","part.fParamMC[].fP[4]!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("param 4 evolution;Iterator;param4")
hq4.Draw()

# %%
tree.SetAlias("gyIn","sin(part.fParamIn[].fAlpha)*part.fParamIn[].fX")
tree.SetAlias("gxIn","cos(part.fParamIn[].fAlpha)*part.fParamIn[].fX")
tree.SetAlias("gzIn","part.fParamIn[].fP[1]")

hqxy = ROOT.TCanvas("hqxy","hqxy",1000,1000)
tree.SetMarkerColor(4)
tree.Draw("gyIn:gxIn","part.fStatusMaskIn[Iteration$]&8192>0 && gxIn!=0","",1,event)
tree.SetMarkerColor(2)
tree.Draw("gyMC:gxMC","gxMC!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetMinimum(-300)  #   Y
h.SetMaximum(300)  #   Y
h.SetTitle("XY view;X[cm];Y[cm]")
el1 = ROOT.TEllipse(0,0,278,278)
el1.SetFillStyle(0)
#el1.Draw("same")
hqxy.Draw()

hqzy = ROOT.TCanvas("hqzy","hqzy",1000,1000)
tree.SetMarkerColor(4)
tree.Draw("gyIn:gzIn","part.fStatusMaskIn[Iteration$]&8192>0 && gzIn!=0","",1,event)
tree.SetMarkerColor(2)
tree.Draw("gyMC:gzMC","gzMC!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("ZY view;Z[cm];Y[cm]")
hqzy.Draw()

# %%
# tree.SetAlias("ptIn","1/abs(part.fParamIn[].fP[4])")
# tree.SetAlias("rIn","TMath::Sqrt((1. - part.fParamIn[].fP[2])*(1. + part.fParamIn[].fP[2]))")
# tree.SetAlias("pxIn","ptIn*(rIn*cos(part.fParamIn[].fAlpha) - part.fParamIn[].fP[2]*sin(part.fParamIn[].fAlpha));")
# tree.SetAlias("pyIn","ptIn*(part.fParamIn[].fP[2]*cos(part.fParamIn[].fAlpha) + rIn*sin(part.fParamIn[].fAlpha));")
# tree.SetAlias("pzIn","ptIn*part.fParamIn[].fP[3]")

# tree.SetAlias("ptMC","1/abs(part.fParamMC[].fP[4])")
# tree.SetAlias("rMC","TMath::Sqrt((1. - part.fParamMC[].fP[2])*(1. + part.fParamMC[].fP[2]))")
# tree.SetAlias("pxMC","ptMC*(rMC*cos(part.fParamMC[].fAlpha) - part.fParamMC[].fP[2]*sin(part.fParamMC[].fAlpha));")
# tree.SetAlias("pyMC","ptMC*(part.fParamMC[].fP[2]*cos(part.fParamMC[].fAlpha) + rIn*sin(part.fParamMC[].fAlpha));")
# tree.SetAlias("pzMC","ptMC*part.fParamMC[].fP[3]")

# hqpx = ROOT.TCanvas("hqpx","hqpx",1000,500)
# tree.SetMarkerColor(4)
# tree.Draw("pxIn[]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0","",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("pxMC[]:Iteration$","part.fParamMC[].fP[4]!=0","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("px evolution;Iterator;param4")
# hqpx.Draw()

# hqpy = ROOT.TCanvas("hqpy","hqpy",1000,500)
# tree.SetMarkerColor(4)
# tree.Draw("pyIn[]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0","",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("pyMC[]:Iteration$","part.fParamMC[].fP[4]!=0","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("py evolution;Iterator;param4")
# hqpy.Draw()

# hqpz = ROOT.TCanvas("hqpz","hqpz",1000,500)
# tree.SetMarkerColor(4)
# tree.Draw("pzIn[]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0","",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("pzMC[]:Iteration$","part.fParamMC[].fP[4]!=0","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("py evolution;Iterator;param4")
# hqpz.Draw()

# %%
hp0 = ROOT.TCanvas("p0","p0",1000,1000)
tree.Draw("(part.fParamIn[].fP[1]-part.fParamMC[].fP[1])/sqrt(part.fParamIn[].fC[3])>>h(100,-2,2)","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[0]!=0","")
hp0.Draw()

# %% [markdown]
# ## OUT

# %%
# event = 5
# tree.SetMarkerSize(2)

# hq0 = ROOT.TCanvas("hq0","hq0",1000,500)
# tree.SetMarkerColor(4)
# tree.Draw("part.fParamOut[].fP[0]:Iteration$","part.fStatusMaskOut[Iteration$]&8192>0","",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("part.fParamMC[].fP[0]:Iteration$","","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("param 0 evolution;Iterator;param0")
# hq0.Draw()

# hq1 = ROOT.TCanvas("hq1","hq1",1000,500)
# tree.SetMarkerColor(4)
# tree.Draw("part.fParamOut[].fP[1]:Iteration$","part.fStatusMaskOut[Iteration$]&8192>0","",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("part.fParamMC[].fP[1]:Iteration$","","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("param 1 evolution;Iterator;param1")
# hq1.Draw()

# hq2 = ROOT.TCanvas("hq2","hq2",1000,500)
# tree.SetMarkerColor(4)
# tree.Draw("part.fParamOut[].fP[2]:Iteration$","part.fStatusMaskOut[Iteration$]&8192>0","",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("part.fParamMC[].fP[2]:Iteration$","","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("param 2 evolution;Iterator;param2")
# hq2.Draw()

# hq3 = ROOT.TCanvas("hq3","hq3",1000,500)
# tree.SetMarkerColor(4)
# tree.Draw("part.fParamOut[].fP[3]:Iteration$","part.fStatusMaskOut[Iteration$]&8192>0","",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("part.fParamMC[].fP[3]:Iteration$","","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("param 3 evolution;Iterator;param3")
# hq3.Draw()

# hq4 = ROOT.TCanvas("hq4","hq4",1000,500)
# tree.SetMarkerColor(4)
# tree.Draw("part.fParamOut[].fP[4]:Iteration$","part.fStatusMaskOut[Iteration$]&8192>0","",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("part.fParamMC[].fP[4]:Iteration$","","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("param 4 evolution;Iterator;param4")
# hq4.Draw()

# %%
# tree.SetAlias("gyOut","sin(part.fParamOut[].fAlpha)*part.fParamOut[].fX")
# tree.SetAlias("gxOut","cos(part.fParamOut[].fAlpha)*part.fParamOut[].fX")
# tree.SetAlias("gzOut","part.fParamOut[].fP[1]")

# hqxy = ROOT.TCanvas("hqxy","hqxy",1000,1000)
# tree.SetMarkerColor(4)
# tree.Draw("gyOut:gxOut","part.fStatusMaskOut[Iteration$]&8192>0","",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("gyMC:gxMC","","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetMinimum(-300)  #   Y
# h.SetMaximum(300)  #   Y
# h.SetTitle("XY view;X[cm];Y[cm]")
# el1 = ROOT.TEllipse(0,0,278,278)
# el1.SetFillStyle(0)
# #el1.Draw("same")
# hqxy.Draw()

# hqzy = ROOT.TCanvas("hqzy","hqzy",1000,1000)
# tree.SetMarkerColor(4)
# tree.Draw("gyOut:gzOut","part.fStatusMaskOut[Iteration$]&8192>0","",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("gyMC:gzMC","","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("ZY view;Z[cm];Y[cm]")
# hqzy.Draw()
