# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from array import array
import os
import sys
import ROOT
from ROOT import TVectorD, TMatrix, TMath, TVector3, TGraphErrors, TFile, TTree, gRandom, gPad, gROOT, gVirtualX, kTRUE, kRed, TProfile, gStyle,  TFile, gSystem
import sys 
import os
sys.path.append(os.path.abspath("/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/fastMCKalman/fastMCKalman/MC/"))
from fastSimulation import *

# %% [markdown]
# # Reading the files

# %%
folder="/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/"
inputData = folder+"fastParticle.list"
ROOT.initTreeFast(inputData)
tree=ROOT.treeFast
treeSeed = ROOT.treeSeed
# Out:
# Number of entries	1
# 0	0	/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/FullReco.root
# Number of entries	1
# 0	0	/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/FullReco.root
# Number of entries	1
# 0	0	/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/FullReco.root
# Number of entries	1
# 0	0	/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/FullReco.root

# %%
event = 7

# %% [markdown]
# ## Parameter Evolution

# %%
tree.SetMarkerSize(1)

hq0 = ROOT.TCanvas("hq0","hq0",1000,500)
tree.SetMarkerColor(5)
tree.Draw("part.fParamRefit[].fP[0]:Iteration$","part.fParamRefit[].fP[0]!=0","",1,event)
tree.SetMarkerColor(4)
tree.Draw("part.fParamIn[].fP[0]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[0]!=0","same",1,event)
tree.SetMarkerColor(3)
tree.Draw("part.fParamOut[].fP[0]:Iteration$","part.fStatusMaskOut[Iteration$]&8192>0 && part.fParamOut[].fP[0]!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("part.fParamMC[].fP[0]:Iteration$","part.fParamMC[].fP[0]!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("param 0 evolution;Iterator;param0")
hq0.Draw()

hq1 = ROOT.TCanvas("hq1","hq1",1000,500)
tree.SetMarkerColor(5)
tree.Draw("part.fParamRefit[].fP[1]:Iteration$"," part.fParamRefit[].fP[1]!=0","",1,event)
tree.SetMarkerColor(4)
tree.Draw("part.fParamIn[].fP[1]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[1]!=0","same",1,event)
tree.SetMarkerColor(3)
tree.Draw("part.fParamOut[].fP[1]:Iteration$","part.fStatusMaskOut[Iteration$]&8192>0 && part.fParamOut[].fP[1]!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("part.fParamMC[].fP[1]:Iteration$","part.fParamMC[].fP[1]!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("param 1 evolution;Iterator;param1")
hq1.Draw()

hq2 = ROOT.TCanvas("hq2","hq2",1000,500)
tree.SetMarkerColor(5)
tree.Draw("part.fParamRefit[].fP[2]:Iteration$"," part.fParamRefit[].fP[2]!=0","",1,event)
tree.SetMarkerColor(4)
tree.Draw("part.fParamIn[].fP[2]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[2]!=0","same",1,event)
tree.SetMarkerColor(3)
tree.Draw("part.fParamOut[].fP[2]:Iteration$","part.fStatusMaskOut[Iteration$]&8192>0 && part.fParamOut[].fP[2]!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("part.fParamMC[].fP[2]:Iteration$","part.fParamMC[].fP[2]!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("param 2 evolution;Iterator;param2")
hq2.Draw()

hq3 = ROOT.TCanvas("hq3","hq3",1000,500)
tree.SetMarkerColor(5)
tree.Draw("part.fParamRefit[].fP[3]:Iteration$"," part.fParamRefit[].fP[3]!=0","",1,event)
tree.SetMarkerColor(4)
tree.Draw("part.fParamIn[].fP[3]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[3]!=0","same",1,event)
tree.SetMarkerColor(3)
tree.Draw("part.fParamOut[].fP[3]:Iteration$","part.fStatusMaskOut[Iteration$]&8192>0 && part.fParamOut[].fP[3]!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("part.fParamMC[].fP[3]:Iteration$","part.fParamMC[].fP[3]!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("param 3 evolution;Iterator;param3")
hq3.Draw()

hq4 = ROOT.TCanvas("hq4","hq4",1000,500)
tree.SetMarkerColor(5)
tree.Draw("part.fParamRefit[].fP[4]:Iteration$"," part.fParamRefit[].fP[4]!=0","",1,event)
tree.SetMarkerColor(4)
tree.Draw("part.fParamIn[].fP[4]:Iteration$","part.fStatusMaskIn[Iteration$]&8192>0 && part.fParamIn[].fP[4]!=0","same",1,event)
tree.SetMarkerColor(3)
tree.Draw("part.fParamOut[].fP[4]:Iteration$","part.fStatusMaskOut[Iteration$]&8192>0 && part.fParamOut[].fP[4]!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("part.fParamMC[].fP[4]:Iteration$","part.fParamMC[].fP[4]!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("param 4 evolution;Iterator;param4")
hq4.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq1
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq2
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq3
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq4

# %% [markdown]
# ## Simple Event Display
# ### First with detector outline, then zoomed in

# %%
tree.SetAlias("gyIn","sin(part.fParamIn[].fAlpha)*part.fParamIn[].fX")
tree.SetAlias("gxIn","cos(part.fParamIn[].fAlpha)*part.fParamIn[].fX")
tree.SetAlias("gzIn","part.fParamIn[].fP[1]")

tree.SetAlias("gyOut","sin(part.fParamOut[].fAlpha)*part.fParamOut[].fX")
tree.SetAlias("gxOut","cos(part.fParamOut[].fAlpha)*part.fParamOut[].fX")
tree.SetAlias("gzOut","part.fParamOut[].fP[1]")

tree.SetAlias("gyRefit","sin(part.fParamRefit[].fAlpha)*part.fParamRefit[].fX")
tree.SetAlias("gxRefit","cos(part.fParamRefit[].fAlpha)*part.fParamRefit[].fX")
tree.SetAlias("gzRefit","part.fParamRefit[].fP[1]")

hqxy = ROOT.TCanvas("hqxy","hqxy",1000,1000)
tree.SetMarkerColor(5)
tree.Draw("gyRefit:gxRefit>>h(100,-300,300,100,-300,300)","gxRefit!=0","",1,event)
tree.SetMarkerColor(4)
tree.Draw("gyIn:gxIn","part.fStatusMaskIn[Iteration$]&8192>0 && gxIn!=0","same",1,event)
tree.SetMarkerColor(3)
tree.Draw("gyOut:gxOut","part.fStatusMaskOut[Iteration$]&8192>0 && gxOut!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("gyMC:gxMC","gxMC!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("h")
h.SetTitle("XY view;X[cm];Y[cm]")
el1 = ROOT.TEllipse(0,0,278,278)
el1.SetFillStyle(0)
el1.Draw("same")
hqxy.Draw()

hqzy = ROOT.TCanvas("hqzy","hqzy",1000,1000)
tree.SetMarkerColor(5)
tree.Draw("gyRefit:gzRefit>>h(100,-300,300,100,-300,300)","gzRefit!=0","",1,event)
tree.SetMarkerColor(4)
tree.Draw("gyIn:gzIn","part.fStatusMaskIn[Iteration$]&8192>0 && gzIn!=0","same",1,event)
tree.SetMarkerColor(3)
tree.Draw("gyOut:gzOut","part.fStatusMaskOut[Iteration$]&8192>0 && gzOut!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("gyMC:gzMC","gzMC!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("h")
h.SetTitle("ZY view;Z[cm];Y[cm]")
box1 = ROOT.TBox(-290,-278,290,278)
box1.SetFillStyle(0)
box1.Draw("same")
hqzy.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqxy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqzy

# %%
tree.SetAlias("gyIn","sin(part.fParamIn[].fAlpha)*part.fParamIn[].fX")
tree.SetAlias("gxIn","cos(part.fParamIn[].fAlpha)*part.fParamIn[].fX")
tree.SetAlias("gzIn","part.fParamIn[].fP[1]")

tree.SetAlias("gyOut","sin(part.fParamOut[].fAlpha)*part.fParamOut[].fX")
tree.SetAlias("gxOut","cos(part.fParamOut[].fAlpha)*part.fParamOut[].fX")
tree.SetAlias("gzOut","part.fParamOut[].fP[1]")

tree.SetAlias("gyRefit","sin(part.fParamRefit[].fAlpha)*part.fParamRefit[].fX")
tree.SetAlias("gxRefit","cos(part.fParamRefit[].fAlpha)*part.fParamRefit[].fX")
tree.SetAlias("gzRefit","part.fParamRefit[].fP[1]")

hqxy = ROOT.TCanvas("hqxy","hqxy",1000,1000)
tree.SetMarkerColor(5)
tree.Draw("gyRefit:gxRefit","gxRefit!=0","",1,event)
tree.SetMarkerColor(4)
tree.Draw("gyIn:gxIn","part.fStatusMaskIn[Iteration$]&8192>0 && gxIn!=0","same",1,event)
tree.SetMarkerColor(3)
tree.Draw("gyOut:gxOut","part.fStatusMaskOut[Iteration$]&8192>0 && gxOut!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("gyMC:gxMC","gxMC!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("XY view;X[cm];Y[cm]")
el1 = ROOT.TEllipse(0,0,278,278)
el1.SetFillStyle(0)
#el1.Draw("same")
hqxy.Draw()

hqzy = ROOT.TCanvas("hqzy","hqzy",1000,1000)
tree.SetMarkerColor(5)
tree.Draw("gyRefit:gzRefit","gzRefit!=0","",1,event)
tree.SetMarkerColor(4)
tree.Draw("gyIn:gzIn","part.fStatusMaskIn[Iteration$]&8192>0 && gzIn!=0","same",1,event)
tree.SetMarkerColor(3)
tree.Draw("gyOut:gzOut","part.fStatusMaskOut[Iteration$]&8192>0 && gzOut!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("gyMC:gzMC","gzMC!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("ZY view;Z[cm];Y[cm]")
box1 = ROOT.TBox(-290,-278,290,278)
box1.SetFillStyle(0)
#box1.Draw("same")
hqzy.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqxy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqzy

# %% [markdown]
# ## Parameter evolution (backward ordering)

# %%
# tree.SetMarkerSize(1)

# hq0 = ROOT.TCanvas("hq0","hq0",1000,500)
# tree.SetMarkerColor(5)
# tree.Draw("partb.fParamRefit[].fP[0]:Iteration$","partb.fParamRefit[].fP[0]!=0","",1,event)
# tree.SetMarkerColor(4)
# tree.Draw("partb.fParamIn[].fP[0]:Iteration$","partb.fStatusMaskIn[Iteration$]&8192>0 && partb.fParamIn[].fP[0]!=0","same",1,event)
# tree.SetMarkerColor(3)
# tree.Draw("partb.fParamOut[].fP[0]:Iteration$","partb.fStatusMaskOut[Iteration$]&8192>0 && partb.fParamOut[].fP[0]!=0","same",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("partb.fParamMC[].fP[0]:Iteration$","partb.fParamMC[].fP[0]!=0","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("param 0 evolution;Iterator;param0")
# hq0.Draw()

# hq1 = ROOT.TCanvas("hq1","hq1",1000,500)
# tree.SetMarkerColor(5)
# tree.Draw("partb.fParamRefit[].fP[1]:Iteration$"," partb.fParamRefit[].fP[1]!=0","",1,event)
# tree.SetMarkerColor(4)
# tree.Draw("partb.fParamIn[].fP[1]:Iteration$","partb.fStatusMaskIn[Iteration$]&8192>0 && partb.fParamIn[].fP[1]!=0","same",1,event)
# tree.SetMarkerColor(3)
# tree.Draw("partb.fParamOut[].fP[1]:Iteration$","partb.fStatusMaskOut[Iteration$]&8192>0 && partb.fParamOut[].fP[1]!=0","same",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("partb.fParamMC[].fP[1]:Iteration$","partb.fParamMC[].fP[1]!=0","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("param 1 evolution;Iterator;param1")
# hq1.Draw()

# hq2 = ROOT.TCanvas("hq2","hq2",1000,500)
# tree.SetMarkerColor(5)
# tree.Draw("partb.fParamRefit[].fP[2]:Iteration$"," partb.fParamRefit[].fP[2]!=0","",1,event)
# tree.SetMarkerColor(4)
# tree.Draw("partb.fParamIn[].fP[2]:Iteration$","partb.fStatusMaskIn[Iteration$]&8192>0 && partb.fParamIn[].fP[2]!=0","same",1,event)
# tree.SetMarkerColor(3)
# tree.Draw("partb.fParamOut[].fP[2]:Iteration$","partb.fStatusMaskOut[Iteration$]&8192>0 && partb.fParamOut[].fP[2]!=0","same",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("partb.fParamMC[].fP[2]:Iteration$","partb.fParamMC[].fP[2]!=0","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("param 2 evolution;Iterator;param2")
# hq2.Draw()

# hq3 = ROOT.TCanvas("hq3","hq3",1000,500)
# tree.SetMarkerColor(5)
# tree.Draw("partb.fParamRefit[].fP[3]:Iteration$"," partb.fParamRefit[].fP[3]!=0","",1,event)
# tree.SetMarkerColor(4)
# tree.Draw("partb.fParamIn[].fP[3]:Iteration$","partb.fStatusMaskIn[Iteration$]&8192>0 && partb.fParamIn[].fP[3]!=0","same",1,event)
# tree.SetMarkerColor(3)
# tree.Draw("partb.fParamOut[].fP[3]:Iteration$","partb.fStatusMaskOut[Iteration$]&8192>0 && partb.fParamOut[].fP[3]!=0","same",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("partb.fParamMC[].fP[3]:Iteration$","partb.fParamMC[].fP[3]!=0","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("param 3 evolution;Iterator;param3")
# hq3.Draw()

# hq4 = ROOT.TCanvas("hq4","hq4",1000,500)
# tree.SetMarkerColor(5)
# tree.Draw("partb.fParamRefit[].fP[4]:Iteration$"," partb.fParamRefit[].fP[4]!=0","",1,event)
# tree.SetMarkerColor(4)
# tree.Draw("partb.fParamIn[].fP[4]:Iteration$","partb.fStatusMaskIn[Iteration$]&8192>0 && partb.fParamIn[].fP[4]!=0","same",1,event)
# tree.SetMarkerColor(3)
# tree.Draw("partb.fParamOut[].fP[4]:Iteration$","partb.fStatusMaskOut[Iteration$]&8192>0 && partb.fParamOut[].fP[4]!=0","same",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("partb.fParamMC[].fP[4]:Iteration$","partb.fParamMC[].fP[4]!=0","same",1,event)
# h = ROOT.gPad.GetPrimitive("htemp")
# h.SetTitle("param 4 evolution;Iterator;param4")
# hq4.Draw()

# %% [markdown]
# ## Simple event display
# ### First with detector outline, then zoomed in

# %%
# tree.SetAlias("gyInb","sin(partb.fParamIn[].fAlpha)*partb.fParamIn[].fX")
# tree.SetAlias("gxInb","cos(partb.fParamIn[].fAlpha)*partb.fParamIn[].fX")
# tree.SetAlias("gzInb","partb.fParamIn[].fP[1]")

# tree.SetAlias("gyOutb","sin(partb.fParamOut[].fAlpha)*partb.fParamOut[].fX")
# tree.SetAlias("gxOutb","cos(partb.fParamOut[].fAlpha)*partb.fParamOut[].fX")
# tree.SetAlias("gzOutb","partb.fParamOut[].fP[1]")

# tree.SetAlias("gyRefitb","sin(partb.fParamRefit[].fAlpha)*partb.fParamRefit[].fX")
# tree.SetAlias("gxRefitb","cos(partb.fParamRefit[].fAlpha)*partb.fParamRefit[].fX")
# tree.SetAlias("gzRefitb","partb.fParamRefit[].fP[1]")

# tree.SetAlias("gyMCb","sin(partb.fParamMC[].fAlpha)*partb.fParamMC[].fX")
# tree.SetAlias("gxMCb","cos(partb.fParamMC[].fAlpha)*partb.fParamMC[].fX")
# tree.SetAlias("gzMCb","partb.fParamMC[].fP[1]")

# hqxy = ROOT.TCanvas("hqxy","hqxy",1000,1000)
# tree.SetMarkerColor(5)
# tree.Draw("gyRefitb:gxRefitb>>h(100,-300,300,100,-300,300)","gxRefitb!=0","",1,event)
# tree.SetMarkerColor(4)
# tree.Draw("gyInb:gxInb","partb.fStatusMaskIn[Iteration$]&8192>0 && gxInb!=0","same",1,event)
# tree.SetMarkerColor(3)
# tree.Draw("gyOutb:gxOutb","partb.fStatusMaskOut[Iteration$]&8192>0 && gxOutb!=0","same",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("gyMCb:gxMCb","gxMCb!=0","same",1,event)
# h = ROOT.gPad.GetPrimitive("h")
# h.SetTitle("XY view;X[cm];Y[cm]")
# el1 = ROOT.TEllipse(0,0,278,278)
# el1.SetFillStyle(0)
# el1.Draw("same")
# hqxy.Draw()

# hqzy = ROOT.TCanvas("hqzy","hqzy",1000,1000)
# tree.SetMarkerColor(5)
# tree.Draw("gyRefitb:gzRefitb>>h(100,-300,300,100,-300,300)","gxRefitb!=0","",1,event)
# tree.SetMarkerColor(4)
# tree.Draw("gyInb:gzInb","partb.fStatusMaskIn[Iteration$]&8192>0 && gxIn!=0","same",1,event)
# tree.SetMarkerColor(3)
# tree.Draw("gyOutb:gzOutb","partb.fStatusMaskOut[Iteration$]&8192>0 && gxOut!=0","same",1,event)
# tree.SetMarkerColor(2)
# tree.Draw("gyMCb:gzMCb","gzMCb!=0","same",1,event)
# h = ROOT.gPad.GetPrimitive("h")
# h.SetTitle("ZY view;Z[cm];Y[cm]")
# box1 = ROOT.TBox(-290,-278,290,278)
# box1.SetFillStyle(0)
# box1.Draw("same")
# hqzy.Draw()

# %%
tree.SetAlias("gyInb","sin(partb.fParamIn[].fAlpha)*partb.fParamIn[].fX")
tree.SetAlias("gxInb","cos(partb.fParamIn[].fAlpha)*partb.fParamIn[].fX")
tree.SetAlias("gzInb","partb.fParamIn[].fP[1]")

tree.SetAlias("gyOutb","sin(partb.fParamOut[].fAlpha)*partb.fParamOut[].fX")
tree.SetAlias("gxOutb","cos(partb.fParamOut[].fAlpha)*partb.fParamOut[].fX")
tree.SetAlias("gzOutb","partb.fParamOut[].fP[1]")

tree.SetAlias("gyRefitb","sin(partb.fParamRefit[].fAlpha)*partb.fParamRefit[].fX")
tree.SetAlias("gxRefitb","cos(partb.fParamRefit[].fAlpha)*partb.fParamRefit[].fX")
tree.SetAlias("gzRefitb","partb.fParamRefit[].fP[1]")

tree.SetAlias("gyMCb","sin(partb.fParamMC[].fAlpha)*partb.fParamMC[].fX")
tree.SetAlias("gxMCb","cos(partb.fParamMC[].fAlpha)*partb.fParamMC[].fX")
tree.SetAlias("gzMCb","partb.fParamMC[].fP[1]")

hqxy = ROOT.TCanvas("hqxy","hqxy",1000,1000)
tree.SetMarkerColor(5)
tree.Draw("gyRefitb:gxRefitb","gxRefitb!=0","",1,event)
tree.SetMarkerColor(4)
tree.Draw("gyInb:gxInb","partb.fStatusMaskIn[Iteration$]&8192>0 && gxInb!=0","same",1,event)
tree.SetMarkerColor(3)
tree.Draw("gyOutb:gxOutb","partb.fStatusMaskOut[Iteration$]&8192>0 && gxOutb!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("gyMCb:gxMCb","gxMCb!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetMinimum(-300)  #   Y
h.SetMaximum(300)  #   Y
h.SetTitle("XY view;X[cm];Y[cm]")
el1 = ROOT.TEllipse(0,0,278,278)
el1.SetFillStyle(0)
#el1.Draw("same")
hqxy.Draw()

hqzy = ROOT.TCanvas("hqzy","hqzy",1000,1000)
tree.SetMarkerColor(4)
tree.Draw("gyInb:gzInb","partb.fStatusMaskIn[Iteration$]&8192>0 && gzIn!=0","",1,event)
tree.SetMarkerColor(3)
tree.Draw("gyOutb:gzOutb","partb.fStatusMaskOut[Iteration$]&8192>0 && gzOut!=0","same",1,event)
tree.SetMarkerColor(2)
tree.Draw("gyMCb:gzMCb","gzMCb!=0","same",1,event)
h = ROOT.gPad.GetPrimitive("htemp")
h.SetTitle("ZY view;Z[cm];Y[cm]")
hqzy.Draw()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [121], line 27
#      25 tree.Draw("gyMCb:gxMCb","gxMCb!=0","same",1,event)
#      26 h = ROOT.gPad.GetPrimitive("htemp")
# ---> 27 h.SetMinimum(-300)  #   Y
#      28 h.SetMaximum(300)  #   Y
#      29 h.SetTitle("XY view;X[cm];Y[cm]")
#
# AttributeError: 'TObject' object has no attribute 'SetMinimum'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqxy
# Error in <TTreeFormula::Compile>:  Bad numerical expression : "partb.fParamRefit[].fAlpha"
# Error in <TTreeFormula::DefinedVariable>: The substitution of the alias "gxRefitb" by "cos(partb.fParamRefit[].fAlpha)*partb.fParamRefit[].fX" failed.
# Info in <TSelectorDraw::AbortProcess>: Variable compilation failed: {gyRefitb:gxRefitb,gxRefitb!=0}
# Error in <TTreeFormula::Compile>:  Bad numerical expression : "partb.fStatusMaskIn[Iteration$]"
# ...
