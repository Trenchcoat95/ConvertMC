# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from array import array
import os
import sys
import ROOT
import Plot_func 
from ROOT import TVectorD, TMatrix, TMath, TVector3, TGraphErrors, TFile, TTree, gRandom, gPad, gROOT, gVirtualX, kTRUE, kRed, TProfile, gStyle,  TFile, gSystem
import sys 
import os
sys.path.append(os.path.abspath("/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/fastMCKalman/fastMCKalman/MC/"))
from fastSimulation import *
# Out:
# Welcome to JupyROOT 6.26/06

# %% [markdown]
# # Reading the files

# %%
folder="/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/"
Recotype = "FullReco"
Interaction = False
ParamTypesave = "InRot"
Particletype = "_muon"
ParamStType = ""
if(ParamTypesave=="InRot") : ParamStType = "NoRot"

sample = ""
inputData = folder+Recotype+"/fastParticle.list"
ROOT.initTreeFast(inputData)
tree = ROOT.treeFast
treeSeed = ROOT.treeSeed
# Out:
# Number of entries	1
# 0	0	/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/FullReco13.000000.root
# Number of entries	1
# 0	0	/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/FullReco13.000000.root
# Number of entries	1
# 0	0	/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/FullReco13.000000.root
# Number of entries	1
# 0	0	/home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/FullReco13.000000.root

# %% [markdown]
# ## ALICE Reconstruction residuals

# %%
save0 =folder+Recotype+"/Plots/"+sample+ParamTypesave+"ALICEResp0.png"
save1 =folder+Recotype+"/Plots/"+sample+ParamTypesave+"ALICEResp1.png"
save2 =folder+Recotype+"/Plots/"+sample+ParamTypesave+"ALICEResp2.png"
save3 =folder+Recotype+"/Plots/"+sample+ParamTypesave+"ALICEResp3.png"
save4 =folder+Recotype+"/Plots/"+sample+ParamTypesave+"ALICEResp4.png"
savep2gaus =folder+Recotype+"/Plots/"+sample+ParamTypesave+"ALICEResp_doublegaus.png"
savep =folder+Recotype+"/Plots/"+sample+ParamTypesave+"ALICEResp_gaus.png"
rangeuser = [0,2500,0,4000,0,1400,0,1600,0,800,0,4500,0,270]
if(Interaction) : rangeuser = [0,2500,0,4000,0,1400,0,1600,0,800,0,2300,0,2300]
ParamType="fParamInRot[0]"

Plot_func.Plot_residuals(tree,ParamType,save0,save1,save2,save3,save4,savep2gaus,savep,rangeuser,"&&fParamMC@.size()>50")
# Out:
#  FCN=262.91 FROM MIGRAD    STATUS=CONVERGED     338 CALLS         339 TOTAL
#                      EDM=6.12329e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   0.9 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A_{core}     6.88139e+01   1.73142e+00   1.96785e-02   1.43300e-01
#    2  #mu_{core}   8.12825e-04   2.31946e-04   3.96036e-07   6.35605e+02
#    3  #sigma_{core}   1.64761e-02   1.88976e-04   3.44157e-05  -3.34897e+01
#    4  A_{tail}     1.86447e+00   1.59803e+00   1.28887e-02   1.53836e-01
#    5  #mu_{tail}   7.16679e-03   2.55591e-04  -8.79122e-05   4.41954e+01
#    6  #sigma_{tail}   1.00736e-02   8.59974e-06  -9.87360e-06   1.83437e+00
#  FCN=314.535 FROM MIGRAD    STATUS=CONVERGED      74 CALLS          75 TOTAL
#                      EDM=7.05937e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.33429e+02   3.27591e+00   2.16923e-02  -1.54413e-05
#    2  Mean         1.06914e-03   1.59714e-04   1.38413e-06   3.78699e-01
#    3  Sigma        1.48890e-02   1.35010e-04   1.81409e-05  -4.74033e-02
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq0
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotALICEResp0.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq1
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotALICEResp1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq2
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotALICEResp2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq3
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotALICEResp3.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq4
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotALICEResp4.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotALICEResp_doublegaus.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqpg
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotALICEResp_gaus.png has been created

# %% [markdown]
# ## GArSoft Recounstruction Residuals

# %%
save0 =folder+Recotype+"/Plots/"+sample+ParamTypesave+"GArSoftResp0.png"
save1 =folder+Recotype+"/Plots/"+sample+ParamTypesave+"GArSoftResp1.png"
save2 =folder+Recotype+"/Plots/"+sample+ParamTypesave+"GArSoftResp2.png"
save3 =folder+Recotype+"/Plots/"+sample+ParamTypesave+"GArSoftResp3.png"
save4 =folder+Recotype+"/Plots/"+sample+ParamTypesave+"GArSoftResp4.png"
savep2gaus =folder+Recotype+"/Plots/"+sample+ParamTypesave+"GArSoftResp_doublegaus.png"
savep =folder+Recotype+"/Plots/"+sample+ParamTypesave+"GArSoftResp_gaus.png"
ParamType="paramStNoRot"

Plot_func.Plot_residuals(tree,ParamType,save0,save1,save2,save3,save4,savep2gaus,savep,rangeuser,"&&fParamMC@.size()>50")
# Out:
#  FCN=57.5844 FROM MIGRAD    STATUS=CONVERGED     571 CALLS         572 TOTAL
#                      EDM=2.08456e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   5.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  A_{core}     8.31972e+00   1.63298e+00   1.44884e-03   3.02614e-04
#    2  #mu_{core}   6.95081e-03   2.10349e-03   1.01021e-06  -6.59296e-02
#    3  #sigma_{core}   5.44368e-02   4.05447e-03  -1.98422e-05   8.51431e-03
#    4  A_{tail}     6.35494e+01   1.75825e+00  -1.63481e-03  -1.61465e-05
#    5  #mu_{tail}   6.66698e-03   3.09230e-04   1.43220e-06  -1.87592e-02
#    6  #sigma_{tail}   2.35402e-02   4.46446e-04  -3.06854e-06   3.14461e-02
#  FCN=271.964 FROM MIGRAD    STATUS=CONVERGED      56 CALLS          57 TOTAL
#                      EDM=4.33697e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.39904e+02   1.98962e+00   1.21081e-02   2.57058e-04
#    2  Mean         6.59179e-03   2.66074e-04   2.14582e-06  -2.79438e+00
#    3  Sigma        2.47721e-02   2.31633e-04   1.83307e-05   2.44949e-01
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq0
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotGArSoftResp0.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq1
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotGArSoftResp1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq2
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotGArSoftResp2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq3
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotGArSoftResp3.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hq4
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotGArSoftResp4.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotGArSoftResp_doublegaus.png has been created
# Info in <TCanvas::Print>: png file /home/federico/Documents/Universita/Federico_2020-2021/Aliwork/ConvertMC/FullReco/Plots/InRotGArSoftResp_gaus.png has been created

# %% [markdown]
# ### Check problematic sample

# %%
ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)
tree.Draw("(fParamMC[0].GetP()-fParamInRot[0].GetP())/fParamMC[0].GetP()>>htempp50(100,-1,1)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()<50&&paramSt.fP[4]!=0","")
hp50 = ROOT.gPad.GetPrimitive("htempp50")
hp50.SetFillColor(ROOT.kRed)
hp50.SetLineColor(ROOT.kRed)
hp50.SetFillStyle(3002)
tree.Draw("(fParamMC[0].GetP()-fParamInRot[0].GetP())/fParamMC[0].GetP()>>htempp(100,-1,1)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&paramSt.fP[4]!=0","")
hp = ROOT.gPad.GetPrimitive("htempp")
hp.SetTitle("ALICE momentum p residual;(p_{reco}-p_{MC})/p_{MC};n")
hqp = ROOT.TCanvas("hqp","hqp",800,600)
hp.Draw()
hp.GetYaxis().SetRangeUser(0,2200)
hp50.Draw("same")
legend = ROOT.TLegend(0.6,0.75,0.88,0.88)
legend.SetBorderSize(0)
legend.AddEntry(hp,"Full sample : "+str(int(hp.GetEntries())),"f")
legend.AddEntry(hp50,"NPoints < 50 : "+str(int(hp50.GetEntries())),"f")
legend.Draw()   
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)
tree.Draw("(fParamMC[0].GetP()-paramSt.GetP())/fParamMC[0].GetP()>>htempp502(100,-1,1)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()<50&&paramSt.fP[4]!=0","")
hp502 = ROOT.gPad.GetPrimitive("htempp502")
hp502.SetFillColor(ROOT.kRed)
hp502.SetLineColor(ROOT.kRed)
hp502.SetFillStyle(3002)
tree.Draw("(fParamMC[0].GetP()-paramSt.GetP())/fParamMC[0].GetP()>>htempp2(100,-1,1)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&paramSt.fP[4]!=0","")
hp2 = ROOT.gPad.GetPrimitive("htempp2")
hp2.SetTitle("GArSoft momentum p residual;(p_{reco}-p_{MC})/p_{MC};n")
hqp2 = ROOT.TCanvas("hqp2","hqp2",800,600)
hp2.Draw()
hp2.GetYaxis().SetRangeUser(0,2200)
hp502.Draw("same")
legend2 = ROOT.TLegend(0.6,0.75,0.88,0.88)
legend2.SetBorderSize(0)
legend2.AddEntry(hp,"Full sample : "+str(int(hp.GetEntries())),"f")
legend2.AddEntry(hp50,"NPoints < 50 : "+str(int(hp50.GetEntries())),"f")
legend2.Draw()  
hqp2.Draw()

# %%
ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)
ROOT.gStyle.SetOptFit(1)
tree.Draw("(fParamMC[0].GetP()-fParamInRot[0].GetP())/fParamMC[0].GetP()>>htempp50(100,-1,1)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()<50&&paramSt.fP[4]!=0","")
hp50 = ROOT.gPad.GetPrimitive("htempp50")
hp50.SetFillColor(ROOT.kRed)
hp50.SetLineColor(ROOT.kRed)
hp50.SetFillStyle(3002)
hp50.SetTitle("ALICE momentum p residual (NPoints<50);(p_{reco}-p_{MC})/p_{MC};n")
hp50.GetYaxis().SetRangeUser(0,1200)
hqp = ROOT.TCanvas("hqp","hqp",800,600)
hp50.Draw()
hp50.Fit("gaus","","",-0.6,0.6)
hqp.Draw()
# Out:
#  FCN=8.35746 FROM MIGRAD    STATUS=CONVERGED      94 CALLS          95 TOTAL
#                      EDM=3.42536e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.61935e+00   3.54141e-01   3.50466e-04  -1.20422e-04
#    2  Mean         1.26226e-01   1.77381e-01   2.52439e-04   1.05660e-03
#    3  Sigma        6.02817e-01   3.70114e-01   3.01298e-04   4.05835e-04
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)
ROOT.gStyle.SetOptFit(1)
tree.Draw("(fParamMC[0].GetP()-paramSt.GetP())/fParamMC[0].GetP()>>htempp50(100,-1,1)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()<50&&paramSt.fP[4]!=0","")
hp50 = ROOT.gPad.GetPrimitive("htempp50")
hp50.SetFillColor(ROOT.kRed)
hp50.SetLineColor(ROOT.kRed)
hp50.SetFillStyle(3002)
hp50.SetTitle("GArSoft momentum p residual (NPoints<50);(p_{reco}-p_{MC})/p_{MC};n")
hp50.GetYaxis().SetRangeUser(0,1200)
hqp = ROOT.TCanvas("hqp","hqp",800,600)
hp50.Draw()
hp50.Fit("gaus","","",-0.6,0.6)
hqp.Draw()
# Out:
#  FCN=8.15148 FROM MIGRAD    STATUS=CONVERGED     142 CALLS         143 TOTAL
#                      EDM=1.19921e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.51077e+00   2.72399e-01   3.22598e-04   4.59562e-05
#    2  Mean         1.89648e-01   1.08039e+00   9.19659e-04   3.07373e-04
#    3  Sigma        1.21017e+00   2.09529e+00   1.27887e-03   1.11544e-04
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)
ROOT.gStyle.SetOptFit(1)
tree.Draw("fParamMC[0].GetP()>>htempp50(100,0,6)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()<50&&paramSt.fP[4]!=0","")
hp50 = ROOT.gPad.GetPrimitive("htempp50")
hp50.SetFillColor(ROOT.kRed)
hp50.SetLineColor(ROOT.kRed)
hp50.SetFillStyle(3002)
hp50.SetTitle("Momentum distribution (NPoints<50);p_{MC};n")
#hp50.GetYaxis().SetRangeUser(0,1200)
hqp = ROOT.TCanvas("hqp","hqp",800,600)
hp50.Draw()
#hp50.Fit("gaus","","",-0.6,0.6)
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)
ROOT.gStyle.SetOptFit(1)
tree.Draw("fParamMC[0].GetP()>>htempp50(100,0,6)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()>50&&paramSt.fP[4]!=0","")
hp50 = ROOT.gPad.GetPrimitive("htempp50")
hp50.SetFillColor(ROOT.kBlue)
hp50.SetLineColor(ROOT.kBlue)
hp50.SetFillStyle(3002)
hp50.SetTitle("Momentum distribution (NPoints>50);p_{MC};n")
#hp50.GetYaxis().SetRangeUser(0,1200)
hqp = ROOT.TCanvas("hqp","hqp",800,600)
hp50.Draw()
#hp50.Fit("gaus","","",-0.6,0.6)
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
tree.SetAlias("yend","part.fParamMC[fParamMC@.size()-1].fX*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)+part.fParamMC[fParamMC@.size()-1].fP[0]*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("ystart","part.fParamMC[0].fX*sin(part.fParamMC[0].fAlpha)+part.fParamMC[0].fP[0]*cos(part.fParamMC[0].fAlpha)")
tree.SetAlias("xend","part.fParamMC[fParamMC@.size()-1].fX*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)-part.fParamMC[fParamMC@.size()-1].fP[0]*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("xstart","part.fParamMC[0].fX*cos(part.fParamMC[0].fAlpha)-part.fParamMC[0].fP[0]*sin(part.fParamMC[0].fAlpha)")
tree.SetAlias("lArmMC","sqrt((xend-xstart)*(xend-xstart)+(yend-ystart)*(yend-ystart))")

tree.Draw("lArmMC>>htempp50(100,0,500)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()>50&&paramSt.fP[4]!=0","")
hp50 = ROOT.gPad.GetPrimitive("htempp50")
hp50.SetFillColor(ROOT.kBlue)
hp50.SetLineColor(ROOT.kBlue)
hp50.SetFillStyle(3002)
hp50.SetTitle("LArm distribution (NPoints>50);LArm_{MC};n")
#hp50.GetYaxis().SetRangeUser(0,1200)
hqp = ROOT.TCanvas("hqp","hqp",800,600)
hp50.Draw()
#hp50.Fit("gaus","","",-0.6,0.6)
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
tree.SetAlias("yend","part.fParamMC[fParamMC@.size()-1].fX*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)+part.fParamMC[fParamMC@.size()-1].fP[0]*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("ystart","part.fParamMC[0].fX*sin(part.fParamMC[0].fAlpha)+part.fParamMC[0].fP[0]*cos(part.fParamMC[0].fAlpha)")
tree.SetAlias("xend","part.fParamMC[fParamMC@.size()-1].fX*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)-part.fParamMC[fParamMC@.size()-1].fP[0]*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("xstart","part.fParamMC[0].fX*cos(part.fParamMC[0].fAlpha)-part.fParamMC[0].fP[0]*sin(part.fParamMC[0].fAlpha)")
tree.SetAlias("lArmMC","sqrt((xend-xstart)*(xend-xstart)+(yend-ystart)*(yend-ystart))")

tree.Draw("lArmMC>>htempp50(100,0,500)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()<50&&paramSt.fP[4]!=0","")
hp50 = ROOT.gPad.GetPrimitive("htempp50")
hp50.SetFillColor(ROOT.kRed)
hp50.SetLineColor(ROOT.kRed)
hp50.SetFillStyle(3002)
hp50.SetTitle("LArm distribution (NPoints<50);LArm_{MC};n")
#hp50.GetYaxis().SetRangeUser(0,1200)
hqp = ROOT.TCanvas("hqp","hqp",800,600)
hp50.Draw()
#hp50.Fit("gaus","","",-0.6,0.6)
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
tree.SetAlias("yend","part.fParamMC[fParamMC@.size()-1].fX*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)+part.fParamMC[fParamMC@.size()-1].fP[0]*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("ystart","part.fParamMC[0].fX*sin(part.fParamMC[0].fAlpha)+part.fParamMC[0].fP[0]*cos(part.fParamMC[0].fAlpha)")
tree.SetAlias("xend","part.fParamMC[fParamMC@.size()-1].fX*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)-part.fParamMC[fParamMC@.size()-1].fP[0]*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("xstart","part.fParamMC[0].fX*cos(part.fParamMC[0].fAlpha)-part.fParamMC[0].fP[0]*sin(part.fParamMC[0].fAlpha)")
tree.SetAlias("lArmMC","sqrt((xend-xstart)*(xend-xstart)+(yend-ystart)*(yend-ystart))")

ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)

hp50.SetTitle("Momentum VS LArm distribution (NPoints>50);p_{MC};LArm;n")

hqp = ROOT.TCanvas("hqp","hqp",800,600)
tree.Draw("lArmMC:fParamMC[0].GetP()>>h(100,0,6,100,0,1000)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()>50&&paramSt.fP[4]!=0","prof")
h = ROOT.gPad.GetPrimitive("h")
h.SetTitle("LArm VS momentum;p_{MC} (GeV/c);LArm_{MC} (cm)")
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
tree.SetAlias("yend","part.fParamMC[fParamMC@.size()-1].fX*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)+part.fParamMC[fParamMC@.size()-1].fP[0]*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("ystart","part.fParamMC[0].fX*sin(part.fParamMC[0].fAlpha)+part.fParamMC[0].fP[0]*cos(part.fParamMC[0].fAlpha)")
tree.SetAlias("xend","part.fParamMC[fParamMC@.size()-1].fX*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)-part.fParamMC[fParamMC@.size()-1].fP[0]*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("xstart","part.fParamMC[0].fX*cos(part.fParamMC[0].fAlpha)-part.fParamMC[0].fP[0]*sin(part.fParamMC[0].fAlpha)")
tree.SetAlias("lArmMC","sqrt((xend-xstart)*(xend-xstart)+(yend-ystart)*(yend-ystart))")

ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)

hp50.SetTitle("Momentum VS LArm distribution (NPoints>50);p_{MC};LArm;n")

hqp = ROOT.TCanvas("hqp","hqp",800,600)
tree.Draw("fParamMC[0].GetP():lArmMC>>h(50,0,500,100,0,6)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()>50&&paramSt.fP[4]!=0","prof")
h = ROOT.gPad.GetPrimitive("h")
h.SetTitle("momentum VS lArmMC;LArm_{MC} (cm);p_{MC} (GeV/c)")
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
tree.SetAlias("yend","part.fParamMC[fParamMC@.size()-1].fX*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)+part.fParamMC[fParamMC@.size()-1].fP[0]*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("ystart","part.fParamMC[0].fX*sin(part.fParamMC[0].fAlpha)+part.fParamMC[0].fP[0]*cos(part.fParamMC[0].fAlpha)")
tree.SetAlias("xend","part.fParamMC[fParamMC@.size()-1].fX*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)-part.fParamMC[fParamMC@.size()-1].fP[0]*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("xstart","part.fParamMC[0].fX*cos(part.fParamMC[0].fAlpha)-part.fParamMC[0].fP[0]*sin(part.fParamMC[0].fAlpha)")
tree.SetAlias("lArmMC","sqrt((xend-xstart)*(xend-xstart)+(yend-ystart)*(yend-ystart))")

ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)

hp50.SetTitle("Momentum VS L distribution (NPoints>50);p_{MC};L (cm);n")

hqp = ROOT.TCanvas("hqp","hqp",800,600)
tree.Draw("fParamMC[0].GetP():fLengthInRot>>h(50,0,750,100,0,6)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()>50&&paramSt.fP[4]!=0","prof")
h = ROOT.gPad.GetPrimitive("h")
h.SetTitle("momentum VS Length;L_{MC} (cm);p_{MC} (GeV/c)")
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)

hp50.SetTitle("Momentum VS L distribution (NPoints>50);p_{MC};L (cm);n")

hqp = ROOT.TCanvas("hqp","hqp",800,600)
tree.Draw("fParamMC[0].GetP():fParamMC@.size()>>h(50,0,750,100,0,6)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()>50&&paramSt.fP[4]!=0","prof")
h = ROOT.gPad.GetPrimitive("h")
h.SetTitle("momentum VS NPoints;NPoints_{MC};p_{MC} (GeV/c)")
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
tree.SetAlias("yend","part.fParamMC[fParamMC@.size()-1].fX*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)+part.fParamMC[fParamMC@.size()-1].fP[0]*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("ystart","part.fParamMC[0].fX*sin(part.fParamMC[0].fAlpha)+part.fParamMC[0].fP[0]*cos(part.fParamMC[0].fAlpha)")
tree.SetAlias("xend","part.fParamMC[fParamMC@.size()-1].fX*cos(part.fParamMC[fParamMC@.size()-1].fAlpha)-part.fParamMC[fParamMC@.size()-1].fP[0]*sin(part.fParamMC[fParamMC@.size()-1].fAlpha)")
tree.SetAlias("xstart","part.fParamMC[0].fX*cos(part.fParamMC[0].fAlpha)-part.fParamMC[0].fP[0]*sin(part.fParamMC[0].fAlpha)")
tree.SetAlias("lArmMC","sqrt((xend-xstart)*(xend-xstart)+(yend-ystart)*(yend-ystart))")

ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)

hp50.SetTitle("Momentum VS LArm distribution (NPoints>50);p_{MC};LArm;n")

hqp = ROOT.TCanvas("hqp","hqp",800,600)
tree.Draw("fLengthInRot:fParamMC[0].GetP()>>h(100,0,6,100,0,1000)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()>50&&paramSt.fP[4]!=0","prof")
h = ROOT.gPad.GetPrimitive("h")
h.SetTitle("Length VS momentum;p_{MC} (GeV/c);Length_{MC} (cm)")
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)

hp50.SetTitle("Momentum VS LArm distribution (NPoints>50);p_{MC};LArm;n")
tree.SetAlias("Radius0MC","1/abs(part.fParamMC[0].fP[4]*5*0.0003)")
hqp = ROOT.TCanvas("hqp","hqp",800,600)
tree.Draw("fLengthInRot/(2*TMath::Pi()*Radius0MC):fParamMC[0].GetP()>>h(100,0,6,100,0,1000)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()>50&&paramSt.fP[4]!=0","prof")
h = ROOT.gPad.GetPrimitive("h")
h.SetTitle("Length/ (2#pir) VS momentum;p_{MC} (GeV/c);Length/ (2#pir)")
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp

# %%
ROOT.gStyle.SetOptFit(kTRUE)
ROOT.gStyle.SetOptStat(0)

hp50.SetTitle("Momentum VS LArm distribution (NPoints>50);p_{MC};LArm;n")
tree.SetAlias("Radius0MC","1/abs(part.fParamMC[0].fP[4]*5*0.0003)")
hqp = ROOT.TCanvas("hqp","hqp",800,600)
tree.Draw("fLengthInRot/(2*TMath::Pi()*Radius0MC):fParamMC@.size()>>h(100,0,700,100,0,1000)","fParamInRot[0].fP[4]!=0&&fParamMC[0].fP[4]!=0&&fParamMC@.size()>50&&paramSt.fP[4]!=0","prof")
h = ROOT.gPad.GetPrimitive("h")
h.SetTitle("Length/ (2#pir) VS NPoints;NPoints (GeV/c);Length/ (2#pir)")
hqp.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hqp
